# %%
# %pip install torchattacks
# %pip install pytorchcv
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: torchattacks in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (3.5.1)
# Requirement already satisfied: torch>=1.7.1 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torchattacks) (2.2.1)
# Requirement already satisfied: torchvision>=0.8.2 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torchattacks) (0.17.1)
# Requirement already satisfied: scipy>=0.14.0 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torchattacks) (1.12.0)
# Requirement already satisfied: tqdm>=4.56.1 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torchattacks) (4.66.2)
# Requirement already satisfied: requests~=2.25.1 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torchattacks) (2.25.1)
# Requirement already satisfied: numpy>=1.19.4 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torchattacks) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from requests~=2.25.1->torchattacks) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from requests~=2.25.1->torchattacks) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from requests~=2.25.1->torchattacks) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from requests~=2.25.1->torchattacks) (2024.2.2)
# Requirement already satisfied: filelock in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torch>=1.7.1->torchattacks) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torch>=1.7.1->torchattacks) (4.10.0)
# Requirement already satisfied: sympy in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torch>=1.7.1->torchattacks) (1.12)
# Requirement already satisfied: networkx in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torch>=1.7.1->torchattacks) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torch>=1.7.1->torchattacks) (3.1.3)
# Requirement already satisfied: fsspec in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torch>=1.7.1->torchattacks) (2024.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torchvision>=0.8.2->torchattacks) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from jinja2->torch>=1.7.1->torchattacks) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from sympy->torch>=1.7.1->torchattacks) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pytorchcv in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (0.0.67)
# Requirement already satisfied: numpy in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from pytorchcv) (1.26.4)
# Requirement already satisfied: requests in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from pytorchcv) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from requests->pytorchcv) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from requests->pytorchcv) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from requests->pytorchcv) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from requests->pytorchcv) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torchattacks in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (3.5.1)
# Requirement already satisfied: pytorchcv in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.0.67)
# Requirement already satisfied: numpy in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: torch in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (2.2.1)
# Requirement already satisfied: torchvision in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (0.17.1)
# Requirement already satisfied: tqdm in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (4.66.2)
# Requirement already satisfied: pillow in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (10.2.0)
# Requirement already satisfied: scipy>=0.14.0 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torchattacks->-r requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: requests~=2.25.1 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torchattacks->-r requirements.txt (line 1)) (2.25.1)
# Requirement already satisfied: filelock in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torch->-r requirements.txt (line 4)) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torch->-r requirements.txt (line 4)) (4.10.0)
# Requirement already satisfied: sympy in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torch->-r requirements.txt (line 4)) (1.12)
# Requirement already satisfied: networkx in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torch->-r requirements.txt (line 4)) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torch->-r requirements.txt (line 4)) (3.1.3)
# Requirement already satisfied: fsspec in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from torch->-r requirements.txt (line 4)) (2024.2.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from requests~=2.25.1->torchattacks->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from requests~=2.25.1->torchattacks->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from requests~=2.25.1->torchattacks->-r requirements.txt (line 1)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from requests~=2.25.1->torchattacks->-r requirements.txt (line 1)) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from jinja2->torch->-r requirements.txt (line 4)) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /Users/walker/miniconda3/envs/spml_HW1/lib/python3.12/site-packages (from sympy->torch->-r requirements.txt (line 4)) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision.utils import save_image

import torchattacks

from tqdm import tqdm
import math
import random
import csv
import torchvision.transforms as transforms
from PIL import Image

# %% [markdown]
# ## Transforms

# %%
# Normally, We don't need augmentations in testing and validation.
# All we need here is to resize the PIL image and transform it into Tensor.
test_tfm = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
])

# However, it is also possible to use augmentation in the testing phase.
# You may use train_tfm to produce a variety of images and then test using ensemble methods
train_tfm = transforms.Compose([
    transforms.Resize((64, 64)),
    # Resize the image into a fixed shape (height = width = 128)
    # You may add some transforms here.
#     transforms.RandomPerspective(distortion_scale=0.3, p=0.5),
#     transforms.RandomRotation(degrees=(0, 180)), 
#     transforms.RandomHorizontalFlip(p=0.5), 
#     transforms.RandomVerticalFlip(p=0.5),
#     transforms.ColorJitter(brightness=0.5, contrast=0.5, hue=0.5, saturation=0.5),
    # transforms.RandomChoice(transform_set_color),
    # transforms.RandomChoice(transform_set_pad),
    # transforms.Resize((128, 128)),
    # ToTensor() should be the last one of the transforms.
    transforms.ToTensor(),
])

# %% [markdown]
# ## Useful Functions

# %% [markdown]
# ### set seeds

# %%
def same_seeds(seed):
    random.seed(seed) 
    np.random.seed(seed)  
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed) 
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# ## Datasets class

# %%
class Cifar100(Dataset):
    def __init__(self, data, labels):
        super(Cifar100, self).__init__()
        self.data = data
        self.labels = labels
        self.datasize = len(self.data)

    def __getitem__(self, idx):
        self.data[idx]
        return self.data[idx], self.labels[idx]
        
            
    def __len__(self):
        return self.datasize

# %% [markdown]
# ## HyperParameters

# %%
config = {
    "batch_size": 1,
    "model_type": "single",
    "attack": "MIFGSM",
    "model_name": "resnet164bn_cifar100",
    "model_names": ['nin_cifar100', 'resnet20_cifar100', 'preresnet20_cifar100', 'seresnet20_cifar100', 'sepreresnet20_cifar100', 'pyramidnet110_a48_cifar100', 'densenet40_k12_cifar100', 'xdensenet40_2_k24_bc_cifar100', 'wrn16_10_cifar100', 'wrn20_10_1bit_cifar100', 'ror3_56_cifar100', 'rir_cifar100', 'resnext29_16x64d_cifar100', 'diaresnet20_cifar100', 'diapreresnet20_cifar100'],
    "test_model_names": ['resnet20_cifar100', 'wrn16_10_cifar100', 'ror3_164_cifar100', 'rir_cifar100', 'pyramidnet110_a270_cifar100', 'resnet110_cifar100', "preresnet164bn_cifar100", "resnext29_32x4d_cifar100", "seresnet164bn_cifar100", 'sepreresnet272bn_cifar100', 'densenet100_k12_cifar100', 'diaresnet164bn_cifar100', 'diapreresnet164bn_cifar100'],
    "data_filepath": "./cifar-100_eval",
    "current_dir": "./",
    "save_dir": "adv_imgs",
    "output_filepath": "./adv_imgs",
    "steps": 16,
    "epsilon": 8 / 255,
    "alpha" : 0.5 / 255,
    "decay": 0.9, 
    "seeds": 10901036
}
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ## Load datasets

# %%
same_seeds(config["seeds"])
eval_files = sorted([os.path.join(config["data_filepath"],x) for x in os.listdir(config["data_filepath"]) if x.endswith(".png")])
eval_imgs = torch.stack([transforms.ToTensor()(Image.open(filename)) for filename in eval_files])
eval_labels = torch.tensor([int(filename.split('/')[-1].split('_')[0]) for filename in eval_files], dtype=torch.long)

# %% [markdown]
# ## Model(s)

# %% [markdown]
# ### Single model

# %%
from pytorchcv.model_provider import get_model as ptcv_get_model
import torchattacks
adv_images = None
if config["model_type"] == "single":
    model_name = config["model_name"]
    model = ptcv_get_model(model_name, pretrained=True).to(device)
    attack = None
    if config["attack"] == "FGSM":
        attack = torchattacks.FGSM(model, eps=config["epsilon"])
    elif config["attack"] == "MIFGSM":
        attack = torchattacks.MIFGSM(model, eps=config["epsilon"], decay=config["decay"], steps=config["steps"])
    elif config["attack"] == "PGD":
        attack = torchattacks.PGD(model, eps=config["epsilon"], alpha=config["alpha"], steps=config["steps"])
    adv_images = attack(eval_imgs, eval_labels)
    with open("attack_info.txt", 'w') as f:
        if config["attack"] == "FGSM":
            f.write(f"Attack: FGSM\nEpsilon: {config['epsilon']}\nModel_type: {config["model_type"]}\nModel: {model_name}\n")
        elif config["attack"] == "PGD":
            f.write(f"Attack: PGD \nEpsilon: {config['epsilon']}\nAlpha: {config["alpha"]}\nSteps: {config["steps"]}\nModel_type: {config["model_type"]}\nModel: {model_name}\n")
        elif config["attack"] == "MIFGSM":
            f.write(f"Attack: MIFGSM \nEpsilon: {config['epsilon']}\nDecay: {config["decay"]}\nSteps: {config["steps"]}\nModel_type: {config["model_type"]}\nModel: {model_name}\n")

# %% [markdown]
# ### Multiple models

# %%
if config["model_type"] == "ensemble":
    model_names = config["model_names"]
    models = [ptcv_get_model(model_name, pretrained=True).to(device) for model_name in model_names]
    with open("attack_info.txt", 'w') as f:
        if config["attack"] == "FGSM":
            f.write(f"Attack: FGSM\nEpsilon: {config['epsilon']}\nModel_type: {config["model_type"]}\nModel: {model_names}\n")
        elif config["attack"] == "PGD":
            f.write(f"Attack: PGD \nEpsilon: {config['epsilon']}\nModel_type: {config["model_type"]}\nAlpha: {config["alpha"]}\nSteps: {config["steps"]}\nModel_type: {config["model_type"]}\nModel: {model_names}\n")
        elif config["attack"] == "MIFGSM":
            f.write(f"Attack: MIFGSM \nEpsilon: {config['epsilon']}\nModel_type: {config["model_type"]}\nDecay: {config["decay"]}\nSteps: {config["steps"]}\nModel_type: {config["model_type"]}\nModel: {model_names}\n")

    final_adv_images = 0
    models_num = len(models)
    for i, model in tqdm(enumerate(models)):
        if config["attack"] == "FGSM":
            attack = torchattacks.FGSM(model, eps=config["epsilon"])
        elif config["attack"] == "MIFGSM":
            attack = torchattacks.MIFGSM(model, eps=config["epsilon"], decay=config["decay"], steps=config["steps"])
        elif config["attack"] == "PGD":
            attack = torchattacks.PGD(model, eps=config["epsilon"], alpha=config["alpha"], steps=config["steps"])
        adv_images = attack(eval_imgs, eval_labels)
        if i==0: 
            final_adv_images = adv_images / models_num
        else:
            final_adv_images += adv_images / models_num

    adv_images = final_adv_images  

if adv_images == None:
    print("No model found.")
    exit()

# %% [markdown]
# ## Save images

# %%
if not os.path.exists(config["save_dir"]):
    os.mkdir(config["save_dir"])
for adv_image, eval_file in zip(adv_images, eval_files):
    save_image(adv_image, os.path.join(config["current_dir"], config["save_dir"], eval_file.split('/')[-1]))

# %% [markdown]
# ## Test Accuracies

# %%
adv_files = sorted([os.path.join(config["output_filepath"], x) for x in os.listdir(config["output_filepath"]) if x.endswith(".png")])
adv_images = torch.stack([transforms.ToTensor()(Image.open(filename)) for filename in adv_files])
adv_labels = torch.tensor([int(filename.split('/')[-1].split('_')[0]) for filename in adv_files], dtype=torch.long)

eval_datasets = Cifar100(eval_imgs, eval_labels)
adv_datasets  = Cifar100(adv_images, adv_labels)

eval_loader = DataLoader(eval_datasets, batch_size=config['batch_size'], shuffle=False, pin_memory=True)
adv_loader  = DataLoader(adv_datasets , batch_size=config['batch_size'], shuffle=False, pin_memory=True)

# %%
test_model_names = config["test_model_names"]
test_models = [ptcv_get_model(test_model_name, pretrained=True).to(device) for test_model_name in test_model_names]

def predict(test_loader, model, device):
    model.eval() # Set your model to evaluation mode.
    acc = 0
    for img, label in tqdm(test_loader):
        img = img.to(device)
        label = label.to(device)
        with torch.no_grad():                   
            pred = model(img) 
            if label[0] == torch.argmax(pred):
                acc += 1
    return acc / 500

for idx, test_model in enumerate(test_models):
    original_acc = predict(eval_loader, test_model, device)
    adv_acc = predict(adv_loader, test_model, device)
    print(f"original images accuracy: {original_acc}")
    print(f"adversarial images accuracy: {adv_acc}")
    print("")
    with open("attack_info.txt", 'a') as f:
        f.write(f"\nTestModel: {test_model_names[idx]}\nOriginal images accuracy: {original_acc}\nAdversarial images accuracy: {adv_acc}\n")
# Out:
# 100%|██████████| 500/500 [00:02<00:00, 189.44it/s]
# 100%|██████████| 500/500 [00:01<00:00, 322.34it/s]
# original images accuracy: 0.496
# adversarial images accuracy: 0.104
# 100%|██████████| 500/500 [00:25<00:00, 19.68it/s]
# 100%|██████████| 500/500 [00:25<00:00, 19.64it/s]
# original images accuracy: 0.978
# adversarial images accuracy: 0.15
# 100%|██████████| 500/500 [00:12<00:00, 40.97it/s]
# 100%|██████████| 500/500 [00:13<00:00, 36.68it/s]
# original images accuracy: 0.862
# adversarial images accuracy: 0.15
# 100%|██████████| 500/500 [00:19<00:00, 25.85it/s]
# 100%|██████████| 500/500 [00:18<00:00, 26.96it/s]
# original images accuracy: 0.952
# adversarial images accuracy: 0.132
# 100%|██████████| 500/500 [01:05<00:00,  7.68it/s]
# 100%|██████████| 500/500 [01:03<00:00,  7.88it/s]
# original images accuracy: 0.986
# adversarial images accuracy: 0.306
# 100%|██████████| 500/500 [00:09<00:00, 53.58it/s]
# 100%|██████████| 500/500 [00:08<00:00, 57.50it/s]
# original images accuracy: 0.808
# adversarial images accuracy: 0.1
# 100%|██████████| 500/500 [00:16<00:00, 30.28it/s]
# 100%|██████████| 500/500 [00:16<00:00, 30.67it/s]
# original images accuracy: 0.926
# adversarial images accuracy: 0.066
# 100%|██████████| 500/500 [00:13<00:00, 36.19it/s]
# 100%|██████████| 500/500 [00:13<00:00, 37.09it/s]
# original images accuracy: 0.952
# adversarial images accuracy: 0.126
# 100%|██████████| 500/500 [00:21<00:00, 23.40it/s]
# 100%|██████████| 500/500 [00:19<00:00, 25.63it/s]
# original images accuracy: 0.788
# adversarial images accuracy: 0.088
# 100%|██████████| 500/500 [00:34<00:00, 14.51it/s]
# 100%|██████████| 500/500 [00:33<00:00, 14.84it/s]
# original images accuracy: 0.794
# adversarial images accuracy: 0.112
# 100%|██████████| 500/500 [01:00<00:00,  8.22it/s]
# 100%|██████████| 500/500 [01:00<00:00,  8.31it/s]
# original images accuracy: 0.936
# adversarial images accuracy: 0.114
# 100%|██████████| 500/500 [00:25<00:00, 19.71it/s]
# 100%|██████████| 500/500 [00:27<00:00, 18.02it/s]
# original images accuracy: 0.848
# adversarial images accuracy: 0.114
# 100%|██████████| 500/500 [00:27<00:00, 18.08it/s]
# 100%|██████████| 500/500 [00:26<00:00, 18.52it/s]
# original images accuracy: 0.9
# adversarial images accuracy: 0.114

# %%
if config["model_type"] == "single":
    os.system(f"zip -r {config['model_name']+"_"+config["attack"]}.zip adv_imgs attack_info.txt")
else:
    model_names = "_".join(config["model_names"])
    os.system(f"zip -r {model_names+"_"+config["attack"]}_step{config["steps"]}.zip adv_imgs attack_info.txt")
# Out:
# updating: adv_imgs/ (stored 0%)
# updating: adv_imgs/29_2.png (stored 0%)
# updating: adv_imgs/91_2.png (stored 0%)
# updating: adv_imgs/12_4.png (stored 0%)
# updating: adv_imgs/57_4.png (stored 0%)
# updating: adv_imgs/48_3.png (stored 0%)
# updating: adv_imgs/93_0.png (stored 0%)
# updating: adv_imgs/88_3.png (stored 0%)
# updating: adv_imgs/53_0.png (stored 0%)
# updating: adv_imgs/16_0.png (stored 0%)
# updating: adv_imgs/30_3.png (stored 0%)
# updating: adv_imgs/75_3.png (stored 0%)
# updating: adv_imgs/97_4.png (stored 0%)
# updating: adv_imgs/8_0.png (stored 0%)
# updating: adv_imgs/14_2.png (stored 0%)
# updating: adv_imgs/51_2.png (stored 0%)
# updating: adv_imgs/77_1.png (stored 0%)
# updating: adv_imgs/32_1.png (stored 0%)
# updating: adv_imgs/77_0.png (stored 0%)
# updating: adv_imgs/32_0.png (stored 0%)
# updating: adv_imgs/14_3.png (stored 0%)
# updating: adv_imgs/51_3.png (stored 0%)
# updating: adv_imgs/8_1.png (stored 0%)
# updating: adv_imgs/30_2.png (stored 0%)
# updating: adv_imgs/75_2.png (stored 0%)
# updating: adv_imgs/53_1.png (stored 0%)
# updating: adv_imgs/16_1.png (stored 0%)
# updating: adv_imgs/88_2.png (stored 0%)
# updating: adv_imgs/36_4.png (stored 0%)
# updating: adv_imgs/73_4.png (stored 0%)
# updating: adv_imgs/93_1.png (stored 0%)
# updating: adv_imgs/48_2.png (stored 0%)
# updating: adv_imgs/91_3.png (stored 0%)
# updating: adv_imgs/29_3.png (stored 0%)
# updating: adv_imgs/29_1.png (stored 0%)
# updating: adv_imgs/91_1.png (stored 0%)
# updating: adv_imgs/34_4.png (stored 0%)
# updating: adv_imgs/71_4.png (stored 0%)
# updating: adv_imgs/48_0.png (stored 0%)
# updating: adv_imgs/93_3.png (stored 0%)
# updating: adv_imgs/88_0.png (stored 0%)
# updating: adv_imgs/75_0.png (stored 0%)
# updating: adv_imgs/30_0.png (stored 0%)
# updating: adv_imgs/16_3.png (stored 0%)
# updating: adv_imgs/53_3.png (stored 0%)
# updating: adv_imgs/8_3.png (stored 0%)
# updating: adv_imgs/32_2.png (stored 0%)
# updating: adv_imgs/77_2.png (stored 0%)
# updating: adv_imgs/51_1.png (stored 0%)
# updating: adv_imgs/14_1.png (stored 0%)
# updating: adv_imgs/51_0.png (stored 0%)
# updating: adv_imgs/14_0.png (stored 0%)
# updating: adv_imgs/32_3.png (stored 0%)
# updating: adv_imgs/77_3.png (stored 0%)
# updating: adv_imgs/8_2.png (stored 0%)
# updating: adv_imgs/16_2.png (stored 0%)
# updating: adv_imgs/53_2.png (stored 0%)
# updating: adv_imgs/75_1.png (stored 0%)
# updating: adv_imgs/30_1.png (stored 0%)
# updating: adv_imgs/95_4.png (stored 0%)
# updating: adv_imgs/68_4.png (stored 0%)
# updating: adv_imgs/88_1.png (stored 0%)
# updating: adv_imgs/10_4.png (stored 0%)
# updating: adv_imgs/55_4.png (stored 0%)
# updating: adv_imgs/93_2.png (stored 0%)
# updating: adv_imgs/48_1.png (stored 0%)
# updating: adv_imgs/91_0.png (stored 0%)
# updating: adv_imgs/29_0.png (stored 0%)
# updating: adv_imgs/29_4.png (stored 0%)
# updating: adv_imgs/12_2.png (stored 0%)
# updating: adv_imgs/57_2.png (stored 0%)
# updating: adv_imgs/71_1.png (stored 0%)
# updating: adv_imgs/34_1.png (stored 0%)
# updating: adv_imgs/91_4.png (stored 0%)
# updating: adv_imgs/55_0.png (stored 0%)
# updating: adv_imgs/10_0.png (stored 0%)
# updating: adv_imgs/36_3.png (stored 0%)
# updating: adv_imgs/73_3.png (stored 0%)
# updating: adv_imgs/68_0.png (stored 0%)
# updating: adv_imgs/95_0.png (stored 0%)
# updating: adv_imgs/14_4.png (stored 0%)
# updating: adv_imgs/51_4.png (stored 0%)
# updating: adv_imgs/97_2.png (stored 0%)
# updating: adv_imgs/97_3.png (stored 0%)
# updating: adv_imgs/95_1.png (stored 0%)
# updating: adv_imgs/30_4.png (stored 0%)
# updating: adv_imgs/75_4.png (stored 0%)
# updating: adv_imgs/88_4.png (stored 0%)
# updating: adv_imgs/68_1.png (stored 0%)
# updating: adv_imgs/36_2.png (stored 0%)
# updating: adv_imgs/73_2.png (stored 0%)
# updating: adv_imgs/55_1.png (stored 0%)
# updating: adv_imgs/10_1.png (stored 0%)
# updating: adv_imgs/48_4.png (stored 0%)
# updating: adv_imgs/71_0.png (stored 0%)
# updating: adv_imgs/34_0.png (stored 0%)
# updating: adv_imgs/12_3.png (stored 0%)
# updating: adv_imgs/57_3.png (stored 0%)
# updating: adv_imgs/34_2.png (stored 0%)
# updating: adv_imgs/71_2.png (stored 0%)
# updating: adv_imgs/57_1.png (stored 0%)
# updating: adv_imgs/12_1.png (stored 0%)
# updating: adv_imgs/73_0.png (stored 0%)
# updating: adv_imgs/36_0.png (stored 0%)
# updating: adv_imgs/10_3.png (stored 0%)
# updating: adv_imgs/55_3.png (stored 0%)
# updating: adv_imgs/68_3.png (stored 0%)
# updating: adv_imgs/95_3.png (stored 0%)
# updating: adv_imgs/32_4.png (stored 0%)
# updating: adv_imgs/77_4.png (stored 0%)
# updating: adv_imgs/97_1.png (stored 0%)
# updating: adv_imgs/8_4.png (stored 0%)
# updating: adv_imgs/97_0.png (stored 0%)
# updating: adv_imgs/95_2.png (stored 0%)
# updating: adv_imgs/16_4.png (stored 0%)
# updating: adv_imgs/53_4.png (stored 0%)
# updating: adv_imgs/68_2.png (stored 0%)
# updating: adv_imgs/93_4.png (stored 0%)
# updating: adv_imgs/10_2.png (stored 0%)
# updating: adv_imgs/55_2.png (stored 0%)
# updating: adv_imgs/73_1.png (stored 0%)
# updating: adv_imgs/36_1.png (stored 0%)
# updating: adv_imgs/57_0.png (stored 0%)
# updating: adv_imgs/12_0.png (stored 0%)
# updating: adv_imgs/34_3.png (stored 0%)
# updating: adv_imgs/71_3.png (stored 0%)
# updating: adv_imgs/9_3.png (stored 0%)
# updating: adv_imgs/76_2.png (stored 0%)
# updating: adv_imgs/33_2.png (stored 0%)
# updating: adv_imgs/15_1.png (stored 0%)
# updating: adv_imgs/50_1.png (stored 0%)
# updating: adv_imgs/89_0.png (stored 0%)
# updating: adv_imgs/31_0.png (stored 0%)
# updating: adv_imgs/74_0.png (stored 0%)
# updating: adv_imgs/52_3.png (stored 0%)
# updating: adv_imgs/17_3.png (stored 0%)
# updating: adv_imgs/49_0.png (stored 0%)
# updating: adv_imgs/92_3.png (stored 0%)
# updating: adv_imgs/28_1.png (stored 0%)
# updating: adv_imgs/90_1.png (stored 0%)
# updating: adv_imgs/70_4.png (stored 0%)
# updating: adv_imgs/35_4.png (stored 0%)
# updating: adv_imgs/90_0.png (stored 0%)
# updating: adv_imgs/28_0.png (stored 0%)
# updating: adv_imgs/54_4.png (stored 0%)
# updating: adv_imgs/11_4.png (stored 0%)
# updating: adv_imgs/92_2.png (stored 0%)
# updating: adv_imgs/49_1.png (stored 0%)
# updating: adv_imgs/52_2.png (stored 0%)
# updating: adv_imgs/17_2.png (stored 0%)
# updating: adv_imgs/31_1.png (stored 0%)
# updating: adv_imgs/74_1.png (stored 0%)
# updating: adv_imgs/94_4.png (stored 0%)
# updating: adv_imgs/69_4.png (stored 0%)
# updating: adv_imgs/89_1.png (stored 0%)
# updating: adv_imgs/15_0.png (stored 0%)
# updating: adv_imgs/50_0.png (stored 0%)
# updating: adv_imgs/76_3.png (stored 0%)
# updating: adv_imgs/33_3.png (stored 0%)
# updating: adv_imgs/9_2.png (stored 0%)
# updating: adv_imgs/96_4.png (stored 0%)
# updating: adv_imgs/9_0.png (stored 0%)
# updating: adv_imgs/50_2.png (stored 0%)
# updating: adv_imgs/15_2.png (stored 0%)
# updating: adv_imgs/33_1.png (stored 0%)
# updating: adv_imgs/76_1.png (stored 0%)
# updating: adv_imgs/89_3.png (stored 0%)
# updating: adv_imgs/17_0.png (stored 0%)
# updating: adv_imgs/52_0.png (stored 0%)
# updating: adv_imgs/74_3.png (stored 0%)
# updating: adv_imgs/31_3.png (stored 0%)
# updating: adv_imgs/49_3.png (stored 0%)
# updating: adv_imgs/92_0.png (stored 0%)
# updating: adv_imgs/28_2.png (stored 0%)
# updating: adv_imgs/90_2.png (stored 0%)
# updating: adv_imgs/56_4.png (stored 0%)
# updating: adv_imgs/13_4.png (stored 0%)
# updating: adv_imgs/90_3.png (stored 0%)
# updating: adv_imgs/28_3.png (stored 0%)
# updating: adv_imgs/72_4.png (stored 0%)
# updating: adv_imgs/37_4.png (stored 0%)
# updating: adv_imgs/92_1.png (stored 0%)
# updating: adv_imgs/49_2.png (stored 0%)
# updating: adv_imgs/74_2.png (stored 0%)
# updating: adv_imgs/31_2.png (stored 0%)
# updating: adv_imgs/17_1.png (stored 0%)
# updating: adv_imgs/52_1.png (stored 0%)
# updating: adv_imgs/89_2.png (stored 0%)
# updating: adv_imgs/33_0.png (stored 0%)
# updating: adv_imgs/76_0.png (stored 0%)
# updating: adv_imgs/50_3.png (stored 0%)
# updating: adv_imgs/15_3.png (stored 0%)
# updating: adv_imgs/9_1.png (stored 0%)
# updating: adv_imgs/76_4.png (stored 0%)
# updating: adv_imgs/33_4.png (stored 0%)
# updating: adv_imgs/96_1.png (stored 0%)
# updating: adv_imgs/69_3.png (stored 0%)
# updating: adv_imgs/94_3.png (stored 0%)
# updating: adv_imgs/37_0.png (stored 0%)
# updating: adv_imgs/72_0.png (stored 0%)
# updating: adv_imgs/54_3.png (stored 0%)
# updating: adv_imgs/11_3.png (stored 0%)
# updating: adv_imgs/70_2.png (stored 0%)
# updating: adv_imgs/35_2.png (stored 0%)
# updating: adv_imgs/13_1.png (stored 0%)
# updating: adv_imgs/56_1.png (stored 0%)
# updating: adv_imgs/13_0.png (stored 0%)
# updating: adv_imgs/56_0.png (stored 0%)
# updating: adv_imgs/70_3.png (stored 0%)
# updating: adv_imgs/35_3.png (stored 0%)
# updating: adv_imgs/92_4.png (stored 0%)
# updating: adv_imgs/54_2.png (stored 0%)
# updating: adv_imgs/11_2.png (stored 0%)
# updating: adv_imgs/37_1.png (stored 0%)
# updating: adv_imgs/72_1.png (stored 0%)
# updating: adv_imgs/94_2.png (stored 0%)
# updating: adv_imgs/52_4.png (stored 0%)
# updating: adv_imgs/17_4.png (stored 0%)
# updating: adv_imgs/69_2.png (stored 0%)
# updating: adv_imgs/9_4.png (stored 0%)
# updating: adv_imgs/96_0.png (stored 0%)
# updating: adv_imgs/50_4.png (stored 0%)
# updating: adv_imgs/15_4.png (stored 0%)
# updating: adv_imgs/96_2.png (stored 0%)
# updating: adv_imgs/69_0.png (stored 0%)
# updating: adv_imgs/94_0.png (stored 0%)
# updating: adv_imgs/11_0.png (stored 0%)
# updating: adv_imgs/54_0.png (stored 0%)
# updating: adv_imgs/72_3.png (stored 0%)
# updating: adv_imgs/37_3.png (stored 0%)
# updating: adv_imgs/28_4.png (stored 0%)
# updating: adv_imgs/56_2.png (stored 0%)
# updating: adv_imgs/13_2.png (stored 0%)
# updating: adv_imgs/35_1.png (stored 0%)
# updating: adv_imgs/70_1.png (stored 0%)
# updating: adv_imgs/90_4.png (stored 0%)
# updating: adv_imgs/35_0.png (stored 0%)
# updating: adv_imgs/70_0.png (stored 0%)
# updating: adv_imgs/56_3.png (stored 0%)
# updating: adv_imgs/13_3.png (stored 0%)
# updating: adv_imgs/72_2.png (stored 0%)
# updating: adv_imgs/37_2.png (stored 0%)
# updating: adv_imgs/11_1.png (stored 0%)
# updating: adv_imgs/54_1.png (stored 0%)
# updating: adv_imgs/49_4.png (stored 0%)
# updating: adv_imgs/94_1.png (stored 0%)
# updating: adv_imgs/74_4.png (stored 0%)
# updating: adv_imgs/31_4.png (stored 0%)
# updating: adv_imgs/89_4.png (stored 0%)
# updating: adv_imgs/69_1.png (stored 0%)
# updating: adv_imgs/96_3.png (stored 0%)
# updating: adv_imgs/78_4.png (stored 0%)
# updating: adv_imgs/98_1.png (stored 0%)
# updating: adv_imgs/65_1.png (stored 0%)
# updating: adv_imgs/20_1.png (stored 0%)
# updating: adv_imgs/43_2.png (stored 0%)
# updating: adv_imgs/85_4.png (stored 0%)
# updating: adv_imgs/22_3.png (stored 0%)
# updating: adv_imgs/67_3.png (stored 0%)
# updating: adv_imgs/41_0.png (stored 0%)
# updating: adv_imgs/39_0.png (stored 0%)
# updating: adv_imgs/3_1.png (stored 0%)
# updating: adv_imgs/81_0.png (stored 0%)
# updating: adv_imgs/58_1.png (stored 0%)
# updating: adv_imgs/1_3.png (stored 0%)
# updating: adv_imgs/45_4.png (stored 0%)
# updating: adv_imgs/83_2.png (stored 0%)
# updating: adv_imgs/83_3.png (stored 0%)
# updating: adv_imgs/1_2.png (stored 0%)
# updating: adv_imgs/58_0.png (stored 0%)
# updating: adv_imgs/81_1.png (stored 0%)
# updating: adv_imgs/24_4.png (stored 0%)
# updating: adv_imgs/61_4.png (stored 0%)
# updating: adv_imgs/3_0.png (stored 0%)
# updating: adv_imgs/39_1.png (stored 0%)
# updating: adv_imgs/41_1.png (stored 0%)
# updating: adv_imgs/22_2.png (stored 0%)
# updating: adv_imgs/67_2.png (stored 0%)
# updating: adv_imgs/19_4.png (stored 0%)
# updating: adv_imgs/43_3.png (stored 0%)
# updating: adv_imgs/65_0.png (stored 0%)
# updating: adv_imgs/20_0.png (stored 0%)
# updating: adv_imgs/98_0.png (stored 0%)
# updating: adv_imgs/7_4.png (stored 0%)
# updating: adv_imgs/98_2.png (stored 0%)
# updating: adv_imgs/43_1.png (stored 0%)
# updating: adv_imgs/20_2.png (stored 0%)
# updating: adv_imgs/65_2.png (stored 0%)
# updating: adv_imgs/5_4.png (stored 0%)
# updating: adv_imgs/41_3.png (stored 0%)
# updating: adv_imgs/67_0.png (stored 0%)
# updating: adv_imgs/22_0.png (stored 0%)
# updating: adv_imgs/39_3.png (stored 0%)
# updating: adv_imgs/3_2.png (stored 0%)
# updating: adv_imgs/81_3.png (stored 0%)
# updating: adv_imgs/58_2.png (stored 0%)
# updating: adv_imgs/1_0.png (stored 0%)
# updating: adv_imgs/26_4.png (stored 0%)
# updating: adv_imgs/63_4.png (stored 0%)
# updating: adv_imgs/83_1.png (stored 0%)
# updating: adv_imgs/83_0.png (stored 0%)
# updating: adv_imgs/1_1.png (stored 0%)
# updating: adv_imgs/58_3.png (stored 0%)
# updating: adv_imgs/81_2.png (stored 0%)
# updating: adv_imgs/47_4.png (stored 0%)
# updating: adv_imgs/3_3.png (stored 0%)
# updating: adv_imgs/39_2.png (stored 0%)
# updating: adv_imgs/87_4.png (stored 0%)
# updating: adv_imgs/67_1.png (stored 0%)
# updating: adv_imgs/22_1.png (stored 0%)
# updating: adv_imgs/41_2.png (stored 0%)
# updating: adv_imgs/20_3.png (stored 0%)
# updating: adv_imgs/65_3.png (stored 0%)
# updating: adv_imgs/43_0.png (stored 0%)
# updating: adv_imgs/98_3.png (stored 0%)
# updating: adv_imgs/7_3.png (stored 0%)
# updating: adv_imgs/78_2.png (stored 0%)
# updating: adv_imgs/85_2.png (stored 0%)
# updating: adv_imgs/43_4.png (stored 0%)
# updating: adv_imgs/5_1.png (stored 0%)
# updating: adv_imgs/19_3.png (stored 0%)
# updating: adv_imgs/87_0.png (stored 0%)
# updating: adv_imgs/24_3.png (stored 0%)
# updating: adv_imgs/61_3.png (stored 0%)
# updating: adv_imgs/47_0.png (stored 0%)
# updating: adv_imgs/83_4.png (stored 0%)
# updating: adv_imgs/63_1.png (stored 0%)
# updating: adv_imgs/26_1.png (stored 0%)
# updating: adv_imgs/45_2.png (stored 0%)
# updating: adv_imgs/45_3.png (stored 0%)
# updating: adv_imgs/63_0.png (stored 0%)
# updating: adv_imgs/26_0.png (stored 0%)
# updating: adv_imgs/1_4.png (stored 0%)
# updating: adv_imgs/47_1.png (stored 0%)
# updating: adv_imgs/24_2.png (stored 0%)
# updating: adv_imgs/61_2.png (stored 0%)
# updating: adv_imgs/22_4.png (stored 0%)
# updating: adv_imgs/67_4.png (stored 0%)
# updating: adv_imgs/87_1.png (stored 0%)
# updating: adv_imgs/19_2.png (stored 0%)
# updating: adv_imgs/5_0.png (stored 0%)
# updating: adv_imgs/85_3.png (stored 0%)
# updating: adv_imgs/78_3.png (stored 0%)
# updating: adv_imgs/7_2.png (stored 0%)
# updating: adv_imgs/7_0.png (stored 0%)
# updating: adv_imgs/98_4.png (stored 0%)
# updating: adv_imgs/78_1.png (stored 0%)
# updating: adv_imgs/85_1.png (stored 0%)
# updating: adv_imgs/20_4.png (stored 0%)
# updating: adv_imgs/65_4.png (stored 0%)
# updating: adv_imgs/5_2.png (stored 0%)
# updating: adv_imgs/19_0.png (stored 0%)
# updating: adv_imgs/87_3.png (stored 0%)
# updating: adv_imgs/3_4.png (stored 0%)
# updating: adv_imgs/47_3.png (stored 0%)
# updating: adv_imgs/61_0.png (stored 0%)
# updating: adv_imgs/24_0.png (stored 0%)
# updating: adv_imgs/58_4.png (stored 0%)
# updating: adv_imgs/45_1.png (stored 0%)
# updating: adv_imgs/26_2.png (stored 0%)
# updating: adv_imgs/63_2.png (stored 0%)
# updating: adv_imgs/26_3.png (stored 0%)
# updating: adv_imgs/63_3.png (stored 0%)
# updating: adv_imgs/45_0.png (stored 0%)
# updating: adv_imgs/61_1.png (stored 0%)
# updating: adv_imgs/24_1.png (stored 0%)
# updating: adv_imgs/47_2.png (stored 0%)
# updating: adv_imgs/81_4.png (stored 0%)
# updating: adv_imgs/39_4.png (stored 0%)
# updating: adv_imgs/41_4.png (stored 0%)
# updating: adv_imgs/87_2.png (stored 0%)
# updating: adv_imgs/19_1.png (stored 0%)
# updating: adv_imgs/5_3.png (stored 0%)
# updating: adv_imgs/85_0.png (stored 0%)
# updating: adv_imgs/78_0.png (stored 0%)
# updating: adv_imgs/7_1.png (stored 0%)
# updating: adv_imgs/59_2.png (stored 0%)
# updating: adv_imgs/0_0.png (stored 0%)
# updating: adv_imgs/62_4.png (stored 0%)
# updating: adv_imgs/27_4.png (stored 0%)
# updating: adv_imgs/82_1.png (stored 0%)
# updating: adv_imgs/38_3.png (stored 0%)
# updating: adv_imgs/2_2.png (stored 0%)
# updating: adv_imgs/80_3.png (stored 0%)
# updating: adv_imgs/4_4.png (stored 0%)
# updating: adv_imgs/40_3.png (stored 0%)
# updating: adv_imgs/23_0.png (stored 0%)
# updating: adv_imgs/66_0.png (stored 0%)
# updating: adv_imgs/99_2.png (stored 0%)
# updating: adv_imgs/42_1.png (stored 0%)
# updating: adv_imgs/64_2.png (stored 0%)
# updating: adv_imgs/21_2.png (stored 0%)
# updating: adv_imgs/64_3.png (stored 0%)
# updating: adv_imgs/21_3.png (stored 0%)
# updating: adv_imgs/42_0.png (stored 0%)
# updating: adv_imgs/99_3.png (stored 0%)
# updating: adv_imgs/86_4.png (stored 0%)
# updating: adv_imgs/23_1.png (stored 0%)
# updating: adv_imgs/66_1.png (stored 0%)
# updating: adv_imgs/40_2.png (stored 0%)
# updating: adv_imgs/80_2.png (stored 0%)
# updating: adv_imgs/46_4.png (stored 0%)
# updating: adv_imgs/2_3.png (stored 0%)
# updating: adv_imgs/38_2.png (stored 0%)
# updating: adv_imgs/82_0.png (stored 0%)
# updating: adv_imgs/0_1.png (stored 0%)
# updating: adv_imgs/59_3.png (stored 0%)
# updating: adv_imgs/59_1.png (stored 0%)
# updating: adv_imgs/0_3.png (stored 0%)
# updating: adv_imgs/44_4.png (stored 0%)
# updating: adv_imgs/82_2.png (stored 0%)
# updating: adv_imgs/38_0.png (stored 0%)
# updating: adv_imgs/2_1.png (stored 0%)
# updating: adv_imgs/80_0.png (stored 0%)
# updating: adv_imgs/66_3.png (stored 0%)
# updating: adv_imgs/23_3.png (stored 0%)
# updating: adv_imgs/40_0.png (stored 0%)
# updating: adv_imgs/79_4.png (stored 0%)
# updating: adv_imgs/99_1.png (stored 0%)
# updating: adv_imgs/21_1.png (stored 0%)
# updating: adv_imgs/64_1.png (stored 0%)
# updating: adv_imgs/42_2.png (stored 0%)
# updating: adv_imgs/84_4.png (stored 0%)
# updating: adv_imgs/42_3.png (stored 0%)
# updating: adv_imgs/21_0.png (stored 0%)
# updating: adv_imgs/64_0.png (stored 0%)
# updating: adv_imgs/99_0.png (stored 0%)
# updating: adv_imgs/6_4.png (stored 0%)
# updating: adv_imgs/40_1.png (stored 0%)
# updating: adv_imgs/66_2.png (stored 0%)
# updating: adv_imgs/23_2.png (stored 0%)
# updating: adv_imgs/18_4.png (stored 0%)
# updating: adv_imgs/80_1.png (stored 0%)
# updating: adv_imgs/60_4.png (stored 0%)
# updating: adv_imgs/25_4.png (stored 0%)
# updating: adv_imgs/2_0.png (stored 0%)
# updating: adv_imgs/38_1.png (stored 0%)
# updating: adv_imgs/82_3.png (stored 0%)
# updating: adv_imgs/0_2.png (stored 0%)
# updating: adv_imgs/59_0.png (stored 0%)
# updating: adv_imgs/59_4.png (stored 0%)
# updating: adv_imgs/44_1.png (stored 0%)
# updating: adv_imgs/62_2.png (stored 0%)
# updating: adv_imgs/27_2.png (stored 0%)
# updating: adv_imgs/2_4.png (stored 0%)
# updating: adv_imgs/46_3.png (stored 0%)
# updating: adv_imgs/25_0.png (stored 0%)
# updating: adv_imgs/60_0.png (stored 0%)
# updating: adv_imgs/4_2.png (stored 0%)
# updating: adv_imgs/18_0.png (stored 0%)
# updating: adv_imgs/86_3.png (stored 0%)
# updating: adv_imgs/6_0.png (stored 0%)
# updating: adv_imgs/99_4.png (stored 0%)
# updating: adv_imgs/79_1.png (stored 0%)
# updating: adv_imgs/84_1.png (stored 0%)
# updating: adv_imgs/64_4.png (stored 0%)
# updating: adv_imgs/21_4.png (stored 0%)
# updating: adv_imgs/84_0.png (stored 0%)
# updating: adv_imgs/79_0.png (stored 0%)
# updating: adv_imgs/6_1.png (stored 0%)
# updating: adv_imgs/40_4.png (stored 0%)
# updating: adv_imgs/86_2.png (stored 0%)
# updating: adv_imgs/18_1.png (stored 0%)
# updating: adv_imgs/4_3.png (stored 0%)
# updating: adv_imgs/25_1.png (stored 0%)
# updating: adv_imgs/60_1.png (stored 0%)
# updating: adv_imgs/46_2.png (stored 0%)
# updating: adv_imgs/80_4.png (stored 0%)
# updating: adv_imgs/38_4.png (stored 0%)
# updating: adv_imgs/62_3.png (stored 0%)
# updating: adv_imgs/27_3.png (stored 0%)
# updating: adv_imgs/44_0.png (stored 0%)
# updating: adv_imgs/82_4.png (stored 0%)
# updating: adv_imgs/27_1.png (stored 0%)
# updating: adv_imgs/62_1.png (stored 0%)
# updating: adv_imgs/44_2.png (stored 0%)
# updating: adv_imgs/60_3.png (stored 0%)
# updating: adv_imgs/25_3.png (stored 0%)
# updating: adv_imgs/46_0.png (stored 0%)
# updating: adv_imgs/4_1.png (stored 0%)
# updating: adv_imgs/18_3.png (stored 0%)
# updating: adv_imgs/86_0.png (stored 0%)
# updating: adv_imgs/6_3.png (stored 0%)
# updating: adv_imgs/79_2.png (stored 0%)
# updating: adv_imgs/84_2.png (stored 0%)
# updating: adv_imgs/42_4.png (stored 0%)
# updating: adv_imgs/84_3.png (stored 0%)
# updating: adv_imgs/79_3.png (stored 0%)
# updating: adv_imgs/6_2.png (stored 0%)
# updating: adv_imgs/66_4.png (stored 0%)
# updating: adv_imgs/23_4.png (stored 0%)
# updating: adv_imgs/86_1.png (stored 0%)
# updating: adv_imgs/18_2.png (stored 0%)
# updating: adv_imgs/4_0.png (stored 0%)
# updating: adv_imgs/46_1.png (stored 0%)
# updating: adv_imgs/60_2.png (stored 0%)
# updating: adv_imgs/25_2.png (stored 0%)
# updating: adv_imgs/44_3.png (stored 0%)
# updating: adv_imgs/27_0.png (stored 0%)
# updating: adv_imgs/62_0.png (stored 0%)
# updating: adv_imgs/0_4.png (stored 0%)
# updating: attack_info.txt (deflated 78%)
